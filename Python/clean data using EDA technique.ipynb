# %%
import pandas as pd

# %%
pd.__version__
# Out:
# '2.2.3'

# %%
emp=pd.read_excel(r'C:\Users\sayed\Downloads\Rawdata.xlsx')

# %%
emp
# Out:
#      Name          Domain       Age   Location   Salary      Exp
# 0    Mike   Datascience#$  34 years     Mumbai   5^00#0       2+
# 1  Teddy^         Testing    45' yr  Bangalore  10%%000       <3
# 2   Uma#r  Dataanalyst^^#       NaN        NaN  1$5%000   4> yrs
# 3    Jane     Ana^^lytics       NaN   Hyderbad   2000^0      NaN
# 4  Uttam*      Statistics     67-yr        NaN   30000-  5+ year
# 5     Kim             NLP      55yr      Delhi  6000^$0      10+

# %%
id(emp)
# Out:
# 1246530541552

# %%
emp.columns
# Out:
# Index(['Name', 'Domain', 'Age', 'Location', 'Salary', 'Exp'], dtype='object')

# %%
emp.shape
# Out:
# (6, 6)

# %%
emp.head()
# Out:
#      Name          Domain       Age   Location   Salary      Exp
# 0    Mike   Datascience#$  34 years     Mumbai   5^00#0       2+
# 1  Teddy^         Testing    45' yr  Bangalore  10%%000       <3
# 2   Uma#r  Dataanalyst^^#       NaN        NaN  1$5%000   4> yrs
# 3    Jane     Ana^^lytics       NaN   Hyderbad   2000^0      NaN
# 4  Uttam*      Statistics     67-yr        NaN   30000-  5+ year

# %%
emp.tail()
# Out:
#      Name          Domain     Age   Location   Salary      Exp
# 1  Teddy^         Testing  45' yr  Bangalore  10%%000       <3
# 2   Uma#r  Dataanalyst^^#     NaN        NaN  1$5%000   4> yrs
# 3    Jane     Ana^^lytics     NaN   Hyderbad   2000^0      NaN
# 4  Uttam*      Statistics   67-yr        NaN   30000-  5+ year
# 5     Kim             NLP    55yr      Delhi  6000^$0      10+

# %%
emp.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 6 entries, 0 to 5
# Data columns (total 6 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   Name      6 non-null      object
#  1   Domain    6 non-null      object
#  2   Age       4 non-null      object
#  3   Location  4 non-null      object
#  4   Salary    6 non-null      object
#  5   Exp       5 non-null      object
# dtypes: object(6)
# memory usage: 420.0+ bytes

# %%
emp
# Out:
#      Name          Domain       Age   Location   Salary      Exp
# 0    Mike   Datascience#$  34 years     Mumbai   5^00#0       2+
# 1  Teddy^         Testing    45' yr  Bangalore  10%%000       <3
# 2   Uma#r  Dataanalyst^^#       NaN        NaN  1$5%000   4> yrs
# 3    Jane     Ana^^lytics       NaN   Hyderbad   2000^0      NaN
# 4  Uttam*      Statistics     67-yr        NaN   30000-  5+ year
# 5     Kim             NLP      55yr      Delhi  6000^$0      10+

# %%
emp.isnull()
# Out:
#     Name  Domain    Age  Location  Salary    Exp
# 0  False   False  False     False   False  False
# 1  False   False  False     False   False  False
# 2  False   False   True      True   False  False
# 3  False   False   True     False   False   True
# 4  False   False  False      True   False  False
# 5  False   False  False     False   False  False

# %%
emp.isna()
# Out:
#     Name  Domain    Age  Location  Salary    Exp
# 0  False   False  False     False   False  False
# 1  False   False  False     False   False  False
# 2  False   False   True      True   False  False
# 3  False   False   True     False   False   True
# 4  False   False  False      True   False  False
# 5  False   False  False     False   False  False

# %% [markdown]
# # Data cleaning or data cleansing

# %%
emp
# Out:
#      Name          Domain       Age   Location   Salary      Exp
# 0    Mike   Datascience#$  34 years     Mumbai   5^00#0       2+
# 1  Teddy^         Testing    45' yr  Bangalore  10%%000       <3
# 2   Uma#r  Dataanalyst^^#       NaN        NaN  1$5%000   4> yrs
# 3    Jane     Ana^^lytics       NaN   Hyderbad   2000^0      NaN
# 4  Uttam*      Statistics     67-yr        NaN   30000-  5+ year
# 5     Kim             NLP      55yr      Delhi  6000^$0      10+

# %%
emp['Name']
# Out:
# 0      Mike
# 1    Teddy^
# 2     Uma#r
# 3      Jane
# 4    Uttam*
# 5       Kim
# Name: Name, dtype: object

# %%
emp['Name'] = emp['Name'].str.replace(r'\W', '', regex = True) #regulsr exoresiions regex

# %%
emp['Name']
# Out:
# 0     Mike
# 1    Teddy
# 2     Umar
# 3     Jane
# 4    Uttam
# 5      Kim
# Name: Name, dtype: object

# %%
emp
# Out:
#     Name          Domain       Age   Location   Salary      Exp
# 0   Mike   Datascience#$  34 years     Mumbai   5^00#0       2+
# 1  Teddy         Testing    45' yr  Bangalore  10%%000       <3
# 2   Umar  Dataanalyst^^#       NaN        NaN  1$5%000   4> yrs
# 3   Jane     Ana^^lytics       NaN   Hyderbad   2000^0      NaN
# 4  Uttam      Statistics     67-yr        NaN   30000-  5+ year
# 5    Kim             NLP      55yr      Delhi  6000^$0      10+

# %%
emp['Domain'] = emp['Domain'].str.replace(r'\W', '', regex = True)

# %%
emp
# Out:
#     Name       Domain       Age   Location   Salary      Exp
# 0   Mike  Datascience  34 years     Mumbai   5^00#0       2+
# 1  Teddy      Testing    45' yr  Bangalore  10%%000       <3
# 2   Umar  Dataanalyst       NaN        NaN  1$5%000   4> yrs
# 3   Jane    Analytics       NaN   Hyderbad   2000^0      NaN
# 4  Uttam   Statistics     67-yr        NaN   30000-  5+ year
# 5    Kim          NLP      55yr      Delhi  6000^$0      10+

# %%
emp['Age'] = emp['Age'].str.replace(r'\W', '', regex = True)

# %%
emp['Age']
# Out:
# 0    34years
# 1       45yr
# 2        NaN
# 3        NaN
# 4       67yr
# 5       55yr
# Name: Age, dtype: object

# %%
emp['Age']=emp['Age'].str.extract('()')

# %%
emp['Age'] = emp['Age'].str.extract(r'(\d+)')

# %%
emp['Age']
# Out:
# 0    NaN
# 1    NaN
# 2    NaN
# 3    NaN
# 4    NaN
# 5    NaN
# Name: Age, dtype: object

# %%
emp
# Out:
#     Name       Domain  Age   Location   Salary      Exp
# 0   Mike  Datascience  NaN     Mumbai   5^00#0       2+
# 1  Teddy      Testing  NaN  Bangalore  10%%000       <3
# 2   Umar  Dataanalyst  NaN        NaN  1$5%000   4> yrs
# 3   Jane    Analytics  NaN   Hyderbad   2000^0      NaN
# 4  Uttam   Statistics  NaN        NaN   30000-  5+ year
# 5    Kim          NLP  NaN      Delhi  6000^$0      10+

# %%
emp['Location'] = emp['Location'].str.replace(r'\W', '', regex = True)

# %%
emp
# Out:
#     Name       Domain  Age   Location   Salary      Exp
# 0   Mike  Datascience  NaN     Mumbai   5^00#0       2+
# 1  Teddy      Testing  NaN  Bangalore  10%%000       <3
# 2   Umar  Dataanalyst  NaN        NaN  1$5%000   4> yrs
# 3   Jane    Analytics  NaN   Hyderbad   2000^0      NaN
# 4  Uttam   Statistics  NaN        NaN   30000-  5+ year
# 5    Kim          NLP  NaN      Delhi  6000^$0      10+

# %%
emp['Salary'] = emp['Salary'].str.replace(r'\W', '', regex = True)

# %%
emp['Salary']
# Out:
# 0     5000
# 1    10000
# 2    15000
# 3    20000
# 4    30000
# 5    60000
# Name: Salary, dtype: object

# %%
emp['Exp'] = emp['Exp'].str.extract(r'(\d+)')

# %%
emp['Exp']
# Out:
# 0      2
# 1      3
# 2      4
# 3    NaN
# 4      5
# 5     10
# Name: Exp, dtype: object

# %%
emp
# Out:
#     Name       Domain  Age   Location Salary  Exp
# 0   Mike  Datascience  NaN     Mumbai   5000    2
# 1  Teddy      Testing  NaN  Bangalore  10000    3
# 2   Umar  Dataanalyst  NaN        NaN  15000    4
# 3   Jane    Analytics  NaN   Hyderbad  20000  NaN
# 4  Uttam   Statistics  NaN        NaN  30000    5
# 5    Kim          NLP  NaN      Delhi  60000   10

# %%
clean_data=emp.copy()

# %%
clean_data
# Out:
#     Name       Domain  Age   Location Salary  Exp
# 0   Mike  Datascience  NaN     Mumbai   5000    2
# 1  Teddy      Testing  NaN  Bangalore  10000    3
# 2   Umar  Dataanalyst  NaN        NaN  15000    4
# 3   Jane    Analytics  NaN   Hyderbad  20000  NaN
# 4  Uttam   Statistics  NaN        NaN  30000    5
# 5    Kim          NLP  NaN      Delhi  60000   10

# %%
#niosy character =,.?

# %% [markdown]
# # Eda techniques will apply

# %%
import numpy as np

# %%
clean_data['Age'].isnull().sum()
# Out:
# np.int64(6)

# %%
emp['Age']
# Out:
# 0    NaN
# 1    NaN
# 2    NaN
# 3    NaN
# 4    NaN
# 5    NaN
# Name: Age, dtype: object

# %%
clean_data['Age'] =  clean_data['Age'].fillna(np.mean( pd.to_numeric(clean_data['Age'])))
# Out:
# C:\Users\sayed\AppData\Local\Temp\ipykernel_17476\2054418259.py:1: FutureWarning: Downcasting object dtype arrays on .fillna, .ffill, .bfill is deprecated and will change in a future version. Call result.infer_objects(copy=False) instead. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   clean_data['Age'] =  clean_data['Age'].fillna(np.mean( pd.to_numeric(clean_data['Age'])))

# %%
clean_data['Age']
# Out:
# 0   NaN
# 1   NaN
# 2   NaN
# 3   NaN
# 4   NaN
# 5   NaN
# Name: Age, dtype: float64

# %%
clean_data['Exp'] =  clean_data['Exp'].fillna(np.mean( pd.to_numeric(clean_data['Exp'])))

# %%
clean_data['Exp']
# Out:
# 0      2
# 1      3
# 2      4
# 3    4.8
# 4      5
# 5     10
# Name: Exp, dtype: object

# %%
clean_data
# Out:
#     Name       Domain  Age   Location Salary  Exp
# 0   Mike  Datascience  NaN     Mumbai   5000    2
# 1  Teddy      Testing  NaN  Bangalore  10000    3
# 2   Umar  Dataanalyst  NaN        NaN  15000    4
# 3   Jane    Analytics  NaN   Hyderbad  20000  4.8
# 4  Uttam   Statistics  NaN        NaN  30000    5
# 5    Kim          NLP  NaN      Delhi  60000   10

# %%
clean_data['Location'].isna().sum()
# Out:
# np.int64(2)

# %%
mode_loc = clean_data['Location'].mode()[0]

# %%
clean_data['Location'] = clean_data['Location'].fillna(mode_loc)

# %%
clean_data['Location']
# Out:
# 0       Mumbai
# 1    Bangalore
# 2    Bangalore
# 3     Hyderbad
# 4    Bangalore
# 5        Delhi
# Name: Location, dtype: object

# %%
clean_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 6 entries, 0 to 5
# Data columns (total 6 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   Name      6 non-null      object
#  1   Domain    6 non-null      object
#  2   Age       0 non-null      float64
#  3   Location  6 non-null      object
#  4   Salary    6 non-null      object
#  5   Exp       6 non-null      object
# dtypes: float64(1), object(5)
# memory usage: 420.0+ bytes

# %%
clean_data['Exp']=clean_data['Exp'].astype(int)

# %%
clean_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 6 entries, 0 to 5
# Data columns (total 6 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   Name      6 non-null      object
#  1   Domain    6 non-null      object
#  2   Age       0 non-null      float64
#  3   Location  6 non-null      object
#  4   Salary    6 non-null      object
#  5   Exp       6 non-null      int64
# dtypes: float64(1), int64(1), object(4)
# memory usage: 420.0+ bytes

# %%
clean_data['Name'] = clean_data['Name'].astype('category')
clean_data['Domain'] = clean_data['Domain'].astype('category')
clean_data['Location'] = clean_data['Location'].astype('category')

# %%
clean_data
# Out:
#     Name       Domain  Age   Location Salary  Exp
# 0   Mike  Datascience  NaN     Mumbai   5000    2
# 1  Teddy      Testing  NaN  Bangalore  10000    3
# 2   Umar  Dataanalyst  NaN  Bangalore  15000    4
# 3   Jane    Analytics  NaN   Hyderbad  20000    4
# 4  Uttam   Statistics  NaN  Bangalore  30000    5
# 5    Kim          NLP  NaN      Delhi  60000   10

# %%
clean_data.to_csv('clean_data.csv')

# %%
import os
os.getcwd() #from os the od gived the saved currner working directly
# Out:
# 'C:\\Users\\sayed'

# %%
clean_data
# Out:
#     Name       Domain  Age   Location Salary  Exp
# 0   Mike  Datascience  NaN     Mumbai   5000    2
# 1  Teddy      Testing  NaN  Bangalore  10000    3
# 2   Umar  Dataanalyst  NaN  Bangalore  15000    4
# 3   Jane    Analytics  NaN   Hyderbad  20000    4
# 4  Uttam   Statistics  NaN  Bangalore  30000    5
# 5    Kim          NLP  NaN      Delhi  60000   10

# %%
import matplotlib.pyplot as plt #visualization

# %%
import seaborn as sns

# %%
import warnings
warnings.filterwarnings('ignore')

# %%
clean_data['Salary']
# Out:
# 0     5000
# 1    10000
# 2    15000
# 3    20000
# 4    30000
# 5    60000
# Name: Salary, dtype: object

# %%
vis1=sns.distplot(clean_data['Salary'])

# %%
vis2=plt.hist(clean_data['Salary'])

# %%
vis5 = sns.lmplot(data=clean_data,x = 'Exp', y='Salary', fit_reg = False)

# %%
clean_data [:]
# Out:
#     Name       Domain  Age   Location Salary  Exp
# 0   Mike  Datascience  NaN     Mumbai   5000    2
# 1  Teddy      Testing  NaN  Bangalore  10000    3
# 2   Umar  Dataanalyst  NaN  Bangalore  15000    4
# 3   Jane    Analytics  NaN   Hyderbad  20000    4
# 4  Uttam   Statistics  NaN  Bangalore  30000    5
# 5    Kim          NLP  NaN      Delhi  60000   10

# %%
clean_data [0:6:2]
# Out:
#     Name       Domain  Age   Location Salary  Exp
# 0   Mike  Datascience  NaN     Mumbai   5000    2
# 2   Umar  Dataanalyst  NaN  Bangalore  15000    4
# 4  Uttam   Statistics  NaN  Bangalore  30000    5

# %%
clean_data[::-1]
# Out:
#     Name       Domain  Age   Location Salary  Exp
# 5    Kim          NLP  NaN      Delhi  60000   10
# 4  Uttam   Statistics  NaN  Bangalore  30000    5
# 3   Jane    Analytics  NaN   Hyderbad  20000    4
# 2   Umar  Dataanalyst  NaN  Bangalore  15000    4
# 1  Teddy      Testing  NaN  Bangalore  10000    3
# 0   Mike  Datascience  NaN     Mumbai   5000    2

# %%
clean_data.columns
# Out:
# Index(['Name', 'Domain', 'Age', 'Location', 'Salary', 'Exp'], dtype='object')

# %%
X_iv = clean_data[['Name', 'Domain', 'Age', 'Location', 'Exp']]

# %%
X_iv
# Out:
#     Name       Domain  Age   Location  Exp
# 0   Mike  Datascience  NaN     Mumbai    2
# 1  Teddy      Testing  NaN  Bangalore    3
# 2   Umar  Dataanalyst  NaN  Bangalore    4
# 3   Jane    Analytics  NaN   Hyderbad    4
# 4  Uttam   Statistics  NaN  Bangalore    5
# 5    Kim          NLP  NaN      Delhi   10

# %%
y_dv=clean_data[['Salary']]

# %%
y_dv
# Out:
#   Salary
# 0   5000
# 1  10000
# 2  15000
# 3  20000
# 4  30000
# 5  60000

# %%
emp
# Out:
#     Name       Domain  Age   Location Salary  Exp
# 0   Mike  Datascience  NaN     Mumbai   5000    2
# 1  Teddy      Testing  NaN  Bangalore  10000    3
# 2   Umar  Dataanalyst  NaN        NaN  15000    4
# 3   Jane    Analytics  NaN   Hyderbad  20000  NaN
# 4  Uttam   Statistics  NaN        NaN  30000    5
# 5    Kim          NLP  NaN      Delhi  60000   10

# %%
clean_data
# Out:
#     Name       Domain  Age   Location Salary  Exp
# 0   Mike  Datascience  NaN     Mumbai   5000    2
# 1  Teddy      Testing  NaN  Bangalore  10000    3
# 2   Umar  Dataanalyst  NaN  Bangalore  15000    4
# 3   Jane    Analytics  NaN   Hyderbad  20000    4
# 4  Uttam   Statistics  NaN  Bangalore  30000    5
# 5    Kim          NLP  NaN      Delhi  60000   10

# %%
X_iv
# Out:
#     Name       Domain  Age   Location  Exp
# 0   Mike  Datascience  NaN     Mumbai    2
# 1  Teddy      Testing  NaN  Bangalore    3
# 2   Umar  Dataanalyst  NaN  Bangalore    4
# 3   Jane    Analytics  NaN   Hyderbad    4
# 4  Uttam   Statistics  NaN  Bangalore    5
# 5    Kim          NLP  NaN      Delhi   10

# %%
y_dv
# Out:
#   Salary
# 0   5000
# 1  10000
# 2  15000
# 3  20000
# 4  30000
# 5  60000

# %%
clean_data
# Out:
#     Name       Domain  Age   Location Salary  Exp
# 0   Mike  Datascience  NaN     Mumbai   5000    2
# 1  Teddy      Testing  NaN  Bangalore  10000    3
# 2   Umar  Dataanalyst  NaN  Bangalore  15000    4
# 3   Jane    Analytics  NaN   Hyderbad  20000    4
# 4  Uttam   Statistics  NaN  Bangalore  30000    5
# 5    Kim          NLP  NaN      Delhi  60000   10

# %%
imputation=pd.get_dummies(clean_data)

# %%
imputation
# Out:
#    Age  Exp  Name_Jane  Name_Kim  Name_Mike  Name_Teddy  Name_Umar  \
# 0  NaN    2      False     False       True       False      False
# 1  NaN    3      False     False      False        True      False
# 2  NaN    4      False     False      False       False       True
# 3  NaN    4       True     False      False       False      False
# 4  NaN    5      False     False      False       False      False
# 5  NaN   10      False      True      False       False      False
#
#    Name_Uttam  Domain_Analytics  Domain_Dataanalyst  ...  Location_Bangalore  \
# 0       False             False               False  ...               False
# 1       False             False               False  ...                True
# 2       False             False                True  ...                True
# 3       False              True               False  ...               False
# 4        True             False               False  ...                True
# ...

# %%
clean_data
# Out:
#     Name       Domain  Age   Location Salary  Exp
# 0   Mike  Datascience  NaN     Mumbai   5000    2
# 1  Teddy      Testing  NaN  Bangalore  10000    3
# 2   Umar  Dataanalyst  NaN  Bangalore  15000    4
# 3   Jane    Analytics  NaN   Hyderbad  20000    4
# 4  Uttam   Statistics  NaN  Bangalore  30000    5
# 5    Kim          NLP  NaN      Delhi  60000   10

# %%
imputation
# Out:
#    Age  Exp  Name_Jane  Name_Kim  Name_Mike  Name_Teddy  Name_Umar  \
# 0  NaN    2      False     False       True       False      False
# 1  NaN    3      False     False      False        True      False
# 2  NaN    4      False     False      False       False       True
# 3  NaN    4       True     False      False       False      False
# 4  NaN    5      False     False      False       False      False
# 5  NaN   10      False      True      False       False      False
#
#    Name_Uttam  Domain_Analytics  Domain_Dataanalyst  ...  Location_Bangalore  \
# 0       False             False               False  ...               False
# 1       False             False               False  ...                True
# 2       False             False                True  ...                True
# 3       False              True               False  ...               False
# 4        True             False               False  ...                True
# ...
